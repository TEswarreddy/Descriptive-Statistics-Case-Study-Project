# %% [markdown]
# <a href="https://colab.research.google.com/github/TEswarreddy/Descriptive-Statistics-Case-Study-Project/blob/main/Descriptive_Statistics_Case_Study_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction**
#
# This Jupyter notebook is part of your learning experiance in the study of descriptive statistics You will work with a simple data set that contains information about  employee.
#
# In these exercise,you will perform the following tasks:
#
#
# 1.   Load and study the data
# 2.   Visualise the distributions of ratings and compensations
# 3.   Subset the data based on thresholds

# %% [markdown]
# # **Task 1- Load the data and study the data**
#
# Load the data and studyits features such as:
#
#
#
# *   The number of employee
# *   The number of features
# *   The types of features

# %%
#Loading "numpy" and "pandas" for manipulating numbers and dataframes
# Load "matplotlib.pyplot" and "seaborn" for data visualization

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read in the "Employee Dataseet" file as a pandas DataFrame

data = pd.read_csv("/content/Employee Dataset.csv")

# %%
#Take a brief look at the data
data.head()
# Out:
#    id groups  age  healthy_eating  active_lifestyle  salary
# 0   0      A   36               5                 5    2297
# 1   1      A   26               3                 5    1134
# 2   2      A   61               8                 1    4969
# 3   3      O   24               3                 6     902
# 4   4      O   39               6                 2    3574

# %%
#Get the Dimensions of the dataframe
data.shape
# Out:
# (50, 6)

# %%
#Get the row names of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
#Get the column names of the dataframe
data.columns
# Out:
# Index(['id', 'groups', 'age', 'healthy_eating', 'active_lifestyle', 'salary'], dtype='object')

# %%
#Look at basic information about the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     int64
#  1   groups            50 non-null     object
#  2   age               50 non-null     int64
#  3   healthy_eating    50 non-null     int64
#  4   active_lifestyle  50 non-null     int64
#  5   salary            50 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.5+ KB

# %% [markdown]
# ## **Observations from Task 1**
#
# There are 50 rows and 6 columns in the data.Each row contains the employee specifics of a certain employee in the company
#
# The features in the data set are:
#
#
#
# 1.   The id of the employee
# 2.   Their respective groups and age
# 3.   Their healthy_eating and active_lifestyle
# 4.   Their salary

# %% [markdown]
# # **# Task 2** - Visualizations the distributions of ratings and compensations
#
# We will now visualize the distributions of employee rating and compensations
#
# We will create the followingplots:
#
#
#
# *   A scatter plot of employee age and employee salry,healthy_eating and active_lifestyle,health_eating and salary
#
# *   A count plot of groups
#
# *  A histogram of employee salary

# %%
#create a scatter plot of the "Age" and "Employee salary " features

plt.figure(figsize=(10,5))
sns.scatterplot(data= data ,x='age',y='salary',color = 'blue',
               edgecolor = 'linen',alpha =0.5 )
plt.title("Scatterplotof Employee Age v/s Employee salary")
plt.xlabel('Employee Age')
plt.ylabel('Employee Salary')
plt.show()

# %% [markdown]
# ### **Observations:**
#
# We observe that in general, there is a relationship between age and Salary of employee
#
# As age increases, the Salary also increases, through there are some otliers present as well

# %%
#create a scatter plot of the "healthy_eating" and "active_lifestyle" features

plt.figure(figsize=(10,5))
sns.scatterplot(data= data ,x='healthy_eating',y='active_lifestyle',color = 'red',
               edgecolor = 'linen',alpha =0.5 )
plt.title("Scatterplotof Healthy Eating v/s Active Lifestyle")
plt.xlabel('Healthy Eating')
plt.ylabel('Active Lifestyle')
plt.show()

# %% [markdown]
# Observations:
#
# We Observe that in general, there is a relationship between healthy_eating and active_lifestyle of employee
#
# As healthy_eating increase , the active_lifestyle also increases

# %%
#create a scatter plot of the "healthy_eating" and "salary" features

plt.figure(figsize=(10,5))
sns.scatterplot(data= data ,x='healthy_eating',y='salary',color = 'black',
               edgecolor = 'linen',alpha =0.5 )
plt.title("Scatterplotof Healthy Eating v/s salary")
plt.xlabel('Healthy Eating')
plt.ylabel('salary')
plt.show()

# %% [markdown]
# Observations:
#
# We observe that in general, there is a relationship between healthy_eatig and Salary of employee
#
# As healthy_eating increases, the salary also increses

# %%
#create countplot of the "groups" features

plt.figure(figsize =(10,5))

sns.countplot(data = data, x='groups',edgecolor ='linen',alpha= 0.7)

plt.title("count plot of Groups")
plt.xlabel("Groups")
plt.ylabel("count")
plt.show()

# %% [markdown]
# Observations:
#
#   We see that most empoyees either belong to Group A or Group O, with group A having maximum frequency

# %%
#creating a histogram of the "salary" feature

plt.figure(figsize =(11,6))

sns.histplot(data =data, x='salary',color = 'orange',
             edgecolor ='linen',alpha =0.7,bins =10)
plt.title("Histogram of Salary")
plt.xlabel("Salary")
plt.ylabel("count")
plt.show()

# %% [markdown]
# Observations:
#
# We see that the salaries are not uniform, which is not necessarily a discrepancy
#
# But we do observe that there are employees with salaries on either extremities of the histogram
#
# Based on the histogram, we can see that the count of highest earning employee is very less

# %% [markdown]
# # **Observation from Task 2**
#
#
#
# 1.   Generally, as the employees age increase, there is a increase in the employee salary
#
# 2.   Generally, as the employees healthy_eating habit increase, there is an increase in the employee salary as well
#
# 3.    However, the employee salary values are more spread out
#
# 4.    An employee of healthy_eating grater than 8 can taken as 8 only
#
# 5.    An employee salary less than 1000 can be considered as a lower salary

# %% [markdown]
# # **Task 3 - Subset the data based on thresholds**
#
#
# We will now subset the original data frame based on the following:
#
#
# *   Employees with healthy_eating greater than 8
# *   Employees with Salary less than 1000
# *   Employees with healthy_eating greater than 8 and with Salary less 100

# %%
#employees healthy_eating is grater than 8
sub1 = data[data['healthy_eating']>8]
sub1
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %%
#salary less than 1000
sub2 = data[data['salary'] < 1000]
sub2
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 3    3      O   24               3                 6     902
# 15  15      B   26               3                 8     662
# 18  18      A   27               2                 6     779
# 26  26      A   62               9                 6     700
# 32  32      A   22               3                 8     662
# 35  35      O   27               2                 4     785
# 38  38     AB   26               3                 7     670
# 39  39      B   29               2                 6     779
# 43  43      O   23               4                10     556

# %%
#Employees with healthy_eating greater than 8 and win salary less than 1000

sub = data[(data['healthy_eating']>8) & (data['salary'] < 1000)]

# %%
sub
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %% [markdown]
# Observations:
#
#
#
# 1.   The only employee seemingly facing a discrepency in salary as compared to healthy_eating is employee who is having id =26
#
# 2.   The employee with id having 26 has a salary of 700

# %% [markdown]
# # **Final conclusions**
#
# From the given data,we can use simple visualisations to get a sense of how data are distributed
#
# We can conduct preliminary simply by subsetting data sets using well thought out thresholds and conditions.
